# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("dashboard_export.xlsx",sheet_name="StateWiseVaccination")
new_df = df[['title','totally_vaccinated']]

# %%
bargraph = df.plot.bar(x = 'title', y = 'totally_vaccinated', fontsize='9')
plt.xlabel('States')
plt.show()
